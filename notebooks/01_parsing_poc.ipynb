# %%
from utils import parsers

# %%
resume_data = parsers.parse_pdf("../data/sample_resumes/test1.pdf")
print(resume_data)
# Out:
# VANSH JAIN
# Noida, India (Open to Remote) • dev.vanshjain@gmail.com • +91-8899372056 • LinkedIn • Portfolio
# SUMMARY
# Software engineer with 1.5+ years shipping production-grade systems end-to-end — RAG pipelines, defence GCS platforms, ATS automation
# from customer brief to live deployment. Strong in LangChain, React Native, and system design. ₹20L+ in scaled ventures. Targeting FDE roles.
# CORE SKILLS
# ● FDE / Solutions: Customer requirement gathering, live deployment, field-testing, product onboarding, cross-team execution
# ● AI & Automation: LangChain, LangGraph, RAG, Claude Code, FastAPI, LLM Prompting, n8n
# ● Frontend & Mobile: React Native, React.js, Redux, TypeScript, JavaScript
# ● Backend & Data: Node.js, Express.js, Nest.js, Python, MongoDB, MySQL, Firebase
# ● DevOps & Infra: Docker, GitHub Actions, Vercel, CI/CD, Git, System Design
# ● Hardware/Field: MAVLink, SITL, ADB Automation, Mapbox, Photogrammetry
# EXPERIENCE
# Botlab Dynamics Noida, India
# Frontend Engineer (Software) Jun 2025 – Present
# Lead development and deployment of an indigenous Ground Control System — core product for the company's new defence vertical.
# ● Deployed RAG-based document intelligence chatbot for internal teams; owned from requirement gathering to production — cut
# document analysis time by 90%.
# ● Built ATS & resume evaluation pipeline with role-specific scoring for hiring stakeholders — reduced manual screening by 70%.
# ● Designed integration/config-switching system for onboarding new defence units onto the GCS platform with zero downtime.
# ● Built 3-tier QA pipeline (2 manual + 1 automated via SITL, react-jest) ensuring reliability for defence-grade field deployment.
# ● Optimised app from 289MB → 57.4MB and CPU usage 60% → 35% for field-hardware constraints via Java multithreading.
# ● Designed path-planning & terrain-mapping feature using RNMapbox and photogrammetry for mission-critical operations.
# Botlab Dynamics Noida, India
# Software Engineering InternDec 2023 – Jun 2025
# Led 60% of codebase for a TypeScript React Native GCS app; managed team of 5; key contributor to winning DRDO iDEX competition.
# ● Resolved critical live-ops crash by building custom throttling hook stabilising drone telemetry (<100ms) from Java MAVLink to React
# Native frontend.
# ● Shipped 60+ animated screens at 60fps using React Native Reanimated, SOLID principles, Redux, useMemo/useCallback.
# ● Integrated field-critical features: media management, screen recording, native module bindings, Mapbox visualisation.
# ENTREPRENEURIAL EXPERIENCE
# TravelTech & Cloud Kitchen Startups(NIT Srinagar)
# Co-founder & Technical Lead2022 – 2024
# ● Scaled two ventures end-to-end — system design, full-stack build (Next.js/Firebase), CMS, order flow, WhatsApp notifications.
# ● Generated ₹20L+ revenue; launched NIT Srinagar's first profitable student venture.
# SELECTED SYSTEMS BUILT
# ● RAG Document Intelligence Chatbot — conversational search across uploaded docs; 90% reduction in analysis time (LangChain +
# FastAPI)
# ● Custom ATS Evaluation Pipeline — role-specific scoring engine; 70% reduction in manual screening
# ● GCS Defence Platform — React Native, MAVLink, Mapbox; DRDO iDEX award-winning system
# ● Multi-integration Config-Switching System — NativeModules-based onboarding for new defence clients
# ● HopeVCare Website — 20+ interdependent features (React.js + Supabase)
# EDUCATION
# National Institute of Technology, SrinagarSrinagar, India
# B.Tech, Electrical EngineeringOct 2021 – Jun 2025
# ● AIR 28, Aerothon '23 — national-level drone innovation challenge.
# ● Final-year research: optimisation algorithms in MATLAB/C++.

# %%
bulk_extraction = parsers.parse_resumes_in_folder("../data/sample_resumes")
print(bulk_extraction)
# Out:
# [{'file_name': 'test1.pdf', 'name': 'VANSH JAIN', 'email': 'dev.vanshjain@gmail.com', 'phone': '+91-8899372056', 'skills': '● FDE / Solutions: Customer requirement gathering, live deployment, field-testing, product onboarding, cross-team execution\n● AI & Automation: LangChain, LangGraph, RAG, Claude Code, FastAPI, LLM Prompting, n8n\n● Frontend & Mobile: React Native, React.js, Redux, TypeScript, JavaScript\n● Backend & Data: Node.js, Express.js, Nest.js, Python, MongoDB, MySQL, Firebase\n● DevOps & Infra: Docker, GitHub Actions, Vercel, CI/CD, Git, System Design\n● Hardware/Field: MAVLink, SITL, ADB Automation, Mapbox, Photogrammetry', 'education': "National Institute of Technology, SrinagarSrinagar, India\nB.Tech, Electrical EngineeringOct 2021 – Jun 2025\n● AIR 28, Aerothon '23 — national-level drone innovation challenge.\n● Final-year research: optimisation algorithms in MATLAB/C++.", 'experience': "Botlab Dynamics Noida, India\nFrontend Engineer (Software) Jun 2025 – Present\nLead development and deployment of an indigenous Ground Control System — core product for the company's new defence vertical.\n● Deployed RAG-based document intelligence chatbot for internal teams; owned from requirement gathering to production — cut\ndocument analysis time by 90%.\n● Built ATS & resume evaluation pipeline with role-specific scoring for hiring stakeholders — reduced manual screening by 70%.\n● Designed integration/config-switching system for onboarding new defence units onto the GCS platform with zero downtime.\n● Built 3-tier QA pipeline (2 manual + 1 automated via SITL, react-jest) ensuring reliability for defence-grade field deployment.\n● Optimised app from 289MB → 57.4MB and CPU usage 60% → 35% for field-hardware constraints via Java multithreading.\n● Designed path-planning & terrain-mapping feature using RNMapbox and photogrammetry for mission-critical operations.\nBotlab Dynamics Noida, India\nSoftware Engineering InternDec 2023 – Jun 2025\nLed 60% of codebase for a TypeScript React Native GCS app; managed team of 5; key contributor to winning DRDO iDEX competition.\n● Resolved critical live-ops crash by building custom throttling hook stabilising drone telemetry (<100ms) from Java MAVLink to React\nNative frontend.\n● Shipped 60+ animated screens at 60fps using React Native Reanimated, SOLID principles, Redux, useMemo/useCallback.\n● Integrated field-critical features: media management, screen recording, native module bindings, Mapbox visualisation.\nENTREPRENEURIAL"}, {'file_name': 'resume-2026.pdf', 'name': 'Sourav Singh Katoch', 'email': 'sourav2003singhkatoch@gmail.com', 'phone': '+91-9797740035', 'skills': 'Languages C++, Python, JavaScript\nWeb & Frameworks React, Next.js, Node.js, Express.js, FastAPI, WebSockets\nDrone & Robotics MAVLink, QGroundControl, geospatial data, photogrammetry, rolling shutter correction\nTools Git, GitHub, VSCode, PyCharm, Postman, Figma, Canva\nDatabases MySQL\nAchievements &', 'education': 'National Institute of Technology, Srinagar 2021 – 2025\nBachelor of Technology, Computer Science and Engineering CGPA: 8.05\nM.H.A.C Nagbani School, Jammu 2021\nBoard of Secondary', 'experience': 'Botlab Dynamics Pvt. Ltd. July 2025 – Present\nBackend Developer Onsite\n• DevelopedbackendalgorithmsinPythonforautonomousdronepathplanning,computingprecisegeographicwaypoints\nfor aerial image capture over polygonal survey areas.\n• Integrated a rolling shutter pipeline to correct image distortion caused by drone motion during capture, improving\naccuracy of 3D reconstruction from survey imagery.\n• ExtendedQGroundControl(QGC)withDJIdronecompatibilityusingtheMAVLinkprotocol, enablingmissionplan-\nning and real-time telemetry for DJI platforms.\n• Integrated geospatial calculations to ensure optimal coverage, overlap, and altitude control for accurate photogram-\nmetry outputs.\nOpen Source Contributions\nLLVM/Clang — Compiler Infrastructure June 2026\ngithub.com/llvm/llvm-project/pull/204891\n• Fixedadiagnos ...
