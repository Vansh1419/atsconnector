# %%
from utils import parsers
bulk_extraction = parsers.parse_resumes_in_folder("../data/sample_resumes")
print(bulk_extraction)

# %%
from utils import normalizers
normalized_results = normalizers.normalize_bulk_resumes(bulk_extraction)

# %%
import json
print(json.dumps(normalized_results[0]['skills'], indent=2))
print(json.dumps(normalized_results[1]['skills'], indent=2))
